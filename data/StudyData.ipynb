# %%
import csv
with open("hierachy.csv", newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter="|")
    for row in reader:

        if len(row) == 3:
            print(row)
# Out:
# ['name', 'parent', 'paperCount']
# ['Impacts of Climate Change on Marine Fisheries', 'Global and Planetary Change', '669']
# ['Impact of Aquaculture on Marine Ecosystems and Food Supply', 'Global and Planetary Change', '276']
# ['Resilience of Coral Reef Ecosystems to Climate Change', 'Ecology', '766']
# ['Climate Change and Variability Research', 'Global and Planetary Change', '140']
# ['Global Methane Emissions and Impacts', 'Global and Planetary Change', '79']
# ['Numerical Weather Prediction Models', 'Atmospheric Science', '23']
# ['Marine Biogeochemistry and Ecosystem Dynamics', 'Oceanography', '462']
# ['Arctic Sea Ice Variability and Decline', 'Atmospheric Science', '148']
# ['Oceanic Modeling and Circulation Studies', 'Oceanography', '211']
# ['Microbial Nitrogen Cycling in Wastewater Treatment Systems', 'Pollution', '7']
# ['Marine Microbial Diversity and Biogeography', 'Ecology', '156']
# ['Marine Biodiversity and Ecosystem Functioning', 'Oceanography', '624']
# ...
